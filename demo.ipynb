# %%
import cv2
import numpy as np
#import preprocess
from preprocess import preprocess
from matplotlib import pyplot as plt
import math

# %matplotlib inline

# %%
#from pdftabextract import imgproc

# %%
from matplotlib import pyplot as plt
#imgfile = 'Image from iOS.jpg'
imgfile = 'sample.jpg'
img = cv2.imread(imgfile)
clean_img = preprocess(imgfile, remove_lines=True)
# Out:
# Angle before correction-89.76226043701172
# Angle after correction-0.23773956298828125
# (3300, 2550)
# (3300, 2550)

# %%
plt.imshow(clean_img, cmap='gray')

# %%
plt.imsave('clean_img_no_lines', clean_img, cmap='gray')
